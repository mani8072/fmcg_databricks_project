-- %%
%sql

CREATE CATALOG IF NOT EXISTS project1_cat;

-- %%
CREATE DATABASE IF NOT EXISTS project1_cat.bronze;
CREATE DATABASE IF NOT EXISTS project1_cat.silver;
CREATE DATABASE IF NOT EXISTS project1_cat.gold;

-- %%
DROP TABLE IF EXISTS project1_cat.gold.fact_orders;
